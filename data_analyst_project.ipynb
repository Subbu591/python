# %% [markdown]
# <a href="https://colab.research.google.com/github/Subbu591/python/blob/main/data_analyst_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/drive/MyDrive/human_cognitive_performance.csv')

# %%
df.head()
# Out:
#   User_ID  Age  Gender  Sleep_Duration  Stress_Level       Diet_Type  \
# 0      U1   57  Female             6.5             3  Non-Vegetarian
# 1      U2   39  Female             7.6             9  Non-Vegetarian
# 2      U3   26    Male             8.2             6      Vegetarian
# 3      U4   32    Male             7.8             9      Vegetarian
# 4      U5   50    Male             9.7             2  Non-Vegetarian
#
#    Daily_Screen_Time Exercise_Frequency  Caffeine_Intake  Reaction_Time  \
# 0                6.5             Medium               41         583.33
# 1               10.8               High              214         368.24
# 2                5.7                Low              429         445.21
# 3                8.3                Low              464         286.33
# 4               11.3             Medium              365         237.65
#
#    Memory_Test_Score  Cognitive_Score  AI_Predicted_Score
# 0                 65            36.71               39.77
# ...

# %%
df.tail()
# Out:
#       User_ID  Age  Gender  Sleep_Duration  Stress_Level       Diet_Type  \
# 79995  U79996   55    Male             7.8             9  Non-Vegetarian
# 79996  U79997   35  Female             9.8             6      Vegetarian
# 79997  U79998   32  Female             7.3            10  Non-Vegetarian
# 79998  U79999   34    Male             8.7             8      Vegetarian
# 79999  U80000   41  Female             7.9             7      Vegetarian
#
#        Daily_Screen_Time Exercise_Frequency  Caffeine_Intake  Reaction_Time  \
# 79995                9.4                Low              157         312.34
# 79996                6.5             Medium              130         290.17
# 79997                7.5                Low              462         249.57
# 79998                7.2             Medium               96         319.48
# 79999                2.0             Medium               27         263.21
#
#        Memory_Test_Score  Cognitive_Score  AI_Predicted_Score
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80000 entries, 0 to 79999
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   User_ID             80000 non-null  object
#  1   Age                 80000 non-null  int64
#  2   Gender              80000 non-null  object
#  3   Sleep_Duration      80000 non-null  float64
#  4   Stress_Level        80000 non-null  int64
#  5   Diet_Type           80000 non-null  object
#  6   Daily_Screen_Time   80000 non-null  float64
#  7   Exercise_Frequency  80000 non-null  object
#  8   Caffeine_Intake     80000 non-null  int64
#  9   Reaction_Time       80000 non-null  float64
#  10  Memory_Test_Score   80000 non-null  int64
#  11  Cognitive_Score     80000 non-null  float64
#  12  AI_Predicted_Score  80000 non-null  float64
# dtypes: float64(5), int64(4), object(4)
# memory usage: 7.9+ MB

# %%
df.describe()
# Out:
#                 Age  Sleep_Duration  Stress_Level  Daily_Screen_Time  \
# count  80000.000000    80000.000000  80000.000000       80000.000000
# mean      38.525525        7.005332      5.493762           6.504646
# std       12.101876        1.734435      2.865308           3.167072
# min       18.000000        4.000000      1.000000           1.000000
# 25%       28.000000        5.500000      3.000000           3.800000
# 50%       39.000000        7.000000      5.000000           6.500000
# 75%       49.000000        8.500000      8.000000           9.200000
# max       59.000000       10.000000     10.000000          12.000000
#
#        Caffeine_Intake  Reaction_Time  Memory_Test_Score  Cognitive_Score  \
# count     80000.000000   80000.000000       80000.000000     80000.000000
# mean        248.988213     399.973579          69.498350        58.172395
# std         144.541990     115.369329          17.305659        23.058522
# ...

# %%
df.isnull().sum()
# Out:
# User_ID               0
# Age                   0
# Gender                0
# Sleep_Duration        0
# Stress_Level          0
# Diet_Type             0
# Daily_Screen_Time     0
# Exercise_Frequency    0
# Caffeine_Intake       0
# Reaction_Time         0
# Memory_Test_Score     0
# Cognitive_Score       0
# AI_Predicted_Score    0
# dtype: int64

# %%
# average cognititve_score
df['Cognitive_Score'].mean()
# Out:
# np.float64(58.172394874999995)

# %%
print(df.columns)
# Out:
# Index(['User_ID', 'Age', 'Gender', 'Sleep_Duration', 'Stress_Level',
#        'Diet_Type', 'Daily_Screen_Time', 'Exercise_Frequency',
#        'Caffeine_Intake', 'Reaction_Time', 'Memory_Test_Score',
#        'Cognitive_Score', 'AI_Predicted_Score'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# User_ID               0
# Age                   0
# Gender                0
# Sleep_Duration        0
# Stress_Level          0
# Diet_Type             0
# Daily_Screen_Time     0
# Exercise_Frequency    0
# Caffeine_Intake       0
# Reaction_Time         0
# Memory_Test_Score     0
# Cognitive_Score       0
# AI_Predicted_Score    0
# dtype: int64

# %%
# what is the average cognitive score across the dataset
df['Cognitive_Score'].mean()
# Out:
# np.float64(58.172394874999995)

# %%
# how does cognitive score vary by age group
df.groupby('Age')['Cognitive_Score'].mean()
# Out:
# Age
# 18    58.591329
# 19    58.260192
# 20    58.865860
# 21    57.693041
# 22    58.252740
# 23    57.635041
# 24    58.148645
# 25    58.391668
# 26    59.666042
# 27    58.616092
# 28    58.127951
# 29    56.965875
# 30    58.299572
# 31    58.159803
# 32    58.692583
# 33    58.231290
# 34    58.395627
# 35    58.496261
# 36    58.285192
# 37    58.027458
# 38    58.600479
# 39    57.964107
# 40    57.924538
# 41    58.910726
# 42    58.537949
# 43    57.878807
# 44    58.217214
# 45    58.340768
# 46    57.843962
# 47    58.174510
# 48    57.790287
# 49    57.410388
# 50    58.637779
# 51    57.764501
# 52    57.064670
# 53    57.479603
# 54    58.621788
# 55    58.748167
# 56    58.697290
# 57    57.045533
# 58    58.094092
# 59    57.722832
# Name: Cognitive_Score, dtype: float64

# %%
#Is there a difference between males and females in cognitive performance
df.groupby('Gender')['Cognitive_Score'].mean()
# Out:
# Gender
# Female    58.220517
# Male      58.100912
# Other     58.444624
# Name: Cognitive_Score, dtype: float64

# %%
# what is the distribution of cognitive scores? is it normal,skewed,etc?
sns.distplot(df['Cognitive_Score'])
# Out:
# <Axes: xlabel='Cognitive_Score', ylabel='Density'>

# %%
# are there correlations between cognitive scores and other variables(eg., education,sleep hours)?
df_numeric = df.select_dtypes(include='number')
correlation_matrix = df_numeric.corr()
print(correlation_matrix)
# Out:
#                          Age  Sleep_Duration  Stress_Level  Daily_Screen_Time  \
# Age                 1.000000        0.000691     -0.000114          -0.002442
# Sleep_Duration      0.000691        1.000000      0.004940          -0.000376
# Stress_Level       -0.000114        0.004940      1.000000          -0.004818
# Daily_Screen_Time  -0.002442       -0.000376     -0.004818           1.000000
# Caffeine_Intake    -0.004267       -0.002482      0.001048          -0.003295
# Reaction_Time       0.004668       -0.009699     -0.011374           0.000094
# Memory_Test_Score  -0.002198       -0.001525      0.000852           0.000315
# Cognitive_Score    -0.005976        0.150595     -0.227639          -0.198515
# AI_Predicted_Score -0.006570        0.149472     -0.225643          -0.196098
#
#                     Caffeine_Intake  Reaction_Time  Memory_Test_Score  \
# Age                       -0.004267       0.004668          -0.002198
# ...

# %%
# average daily screen time of females
df[df['Gender']=='Female']['Daily_Screen_Time'].mean()
# Out:
# np.float64(6.484722945526507)

# %%
# how does cognitive performance change with age overtime
df.groupby('Age')['Cognitive_Score'].mean()
# Out:
# Age
# 18    58.591329
# 19    58.260192
# 20    58.865860
# 21    57.693041
# 22    58.252740
# 23    57.635041
# 24    58.148645
# 25    58.391668
# 26    59.666042
# 27    58.616092
# 28    58.127951
# 29    56.965875
# 30    58.299572
# 31    58.159803
# 32    58.692583
# 33    58.231290
# 34    58.395627
# 35    58.496261
# 36    58.285192
# 37    58.027458
# 38    58.600479
# 39    57.964107
# 40    57.924538
# 41    58.910726
# 42    58.537949
# 43    57.878807
# 44    58.217214
# 45    58.340768
# 46    57.843962
# 47    58.174510
# 48    57.790287
# 49    57.410388
# 50    58.637779
# 51    57.764501
# 52    57.064670
# 53    57.479603
# 54    58.621788
# 55    58.748167
# 56    58.697290
# 57    57.045533
# 58    58.094092
# 59    57.722832
# Name: Cognitive_Score, dtype: float64

# %%
# show average caffeine_intake of both males and females
df.groupby('Gender')['Caffeine_Intake'].mean()
# Out:
# Gender
# Female    249.158343
# Male      248.672903
# Other     250.683262
# Name: Caffeine_Intake, dtype: float64

# %% [markdown]
# # New Section
